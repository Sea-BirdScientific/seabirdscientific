# %%
# Example when calling plotting functions directly

from sbs.visualization import data_visualization as dv


source = 'orca-test-data\SBE37SM\SBE37SM-RS232_03711722_2015_11_18\SBE37SM-RS232_03711722_2015_11_18.csv'
config = dv.ChartConfig(
    title = source,
    y_names = ['density00'],
    x_names = ['t090C', 'sal00','svCM'],
    z_names = [],
    chart_type = "subplots",
    bounds={
        # 'x': { 0: [6700, 6950] },
        # 'y': { 0: [29, 32], 1: [29, 32], 2: [29, 32], 3: [29, 32] }
        },
    plot_loop_edit_flags=False,
    lift_pen_over_bad_data=False
)

data = dv.ChartData(source, config)

line = dv.plot_xy_chart(data, config)
line.show()

# %%
# Example when calling plotting functions directly

from sbs.visualization import data_visualization as dv


source = 'orca-test-data\SBE19\CAST0002\CAST0002.cnv'
config = dv.ChartConfig(
    title = source,
    x_names = ['t090C', 'c0S/m'],
    y_names = ['prSM'],
    z_names = [],
    chart_type = "overlay",
    bounds={
        'x': { 0: [7, 13], 1: [2, 4] },
        # 'y': { 0: [29, 32], 1: [29, 32], 2: [29, 32], 3: [29, 32] }
        },
    plot_loop_edit_flags=False,
    lift_pen_over_bad_data=False
)

data = dv.ChartData(source, config)

fig = dv.plot_xy_chart(data, config)
fig['layout']['yaxis']['autorange'] = "reversed"
fig.update_layout(height=800)
fig.show()

# %%
# Example when calling plotting functions directly

from sbs.visualization import data_visualization as dv


source = 'orca-test-data\SBE37SM\SBE37SM-RS232_03711722_2015_11_18\SBE37SM-RS232_03711722_2015_11_18.csv'
config = dv.ChartConfig(
    title = source,
    x_names = ['t090C', 'c0S/m'],
    y_names = ['prM'],
    z_names = [],
    chart_type = "overlay",
    bounds={
        # 'x': { 0: [6700, 6950] },
        # 'y': { 0: [29, 32], 1: [29, 32], 2: [29, 32], 3: [29, 32] }
        },
    plot_loop_edit_flags=False,
    lift_pen_over_bad_data=False
)

data = dv.ChartData(source, config)

line = dv.plot_xy_chart(data, config)
line.show()

# %%
# Example when calling plotting functions directly

from sbs.visualization import data_visualization as dv


source = 'orca-test-data\SBE37SM\SBE37SM-RS232_03711722_2015_11_18\SBE37SM-RS232_03711722_2015_11_18_filtered_scipy.csv'
config = dv.ChartConfig(
    title = source,
    x_names = [],
    y_names = ["t090C", 't090C_1000', 't090C_3000', 't090C_10000'],
    z_names = [],
    chart_type = "overlay",
    bounds={
        'x': { 0: [6700, 6950] },
        'y': { 0: [29, 32], 1: [29, 32], 2: [29, 32], 3: [29, 32] }
        },
    plot_loop_edit_flags=False,
    lift_pen_over_bad_data=False
)

data = dv.ChartData(source, config)

line = dv.plot_xy_chart(data, config)
line.show()

# %%
# Example when calling api function intended for React Native

from sbs.visualization import data_visualization as dv

source = '{"Col1": [1.0, 4.0, 7.0], "Col2": [2.0, 5.0, 8.0], "Col3": [3.0, 6.0, 9.0], "flag": [0.0, 0.0, 0.0]}'
dv.api_xy_chart_html(
    source=source,
    title=source,
    x_names=["Col1"],
    y_names=["Col2"],
    z_names=[],
    chart_type="subplots"
)

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("orca-test-data\SBE37SM\SBE37SM-RS232_03711722_2015_11_18\SBE37SM-RS232_03711722_2015_11_18.csv")
time_j = data['timeJ'].values
interval = np.mean(np.diff(time_j))*60*60*24
sampling_freq = 1 / interval

time_constants = [10, 100, 1000] # == 1/(2*pi*f)
f = [1 / (2 * np.pi * time_constant) for time_constant in time_constants]
t = [1 / freq for freq in f]

# %%
# Example when calling plotting functions directly

from sbs.visualization import data_visualization as dv


source = 'orca-test-data\SBE37SM\SBE37SM-RS232_03711722_2015_11_18\SBE37SM-RS232_03711722_2015_11_18_flag.cnv'
config = dv.ChartConfig(
    title = source,
    x_names = [],
    y_names = ["t090C", 'c0S/m'],
    z_names = [],
    chart_type = "overlay",
    bounds={
        # 'x': { 0: [6700, 6950] },
        # 'y': { 0: [29, 32], 1: [29, 32], 2: [29, 32], 3: [29, 32] }
        },
    plot_loop_edit_flags=False,
    lift_pen_over_bad_data=False
)

data = dv.ChartData(source, config)

line = dv.plot_xy_chart(data, config)
line.show()

# %%
# Example when calling plotting functions directly

from sbs.visualization import data_visualization as dv


# source = 'data_x/SBE37SM-RS232_03711722_2015_11_18_flag.asc'
source = 'orca-test-data\SBE37SM\SBE37SM-RS232_03711722_2015_11_18\SBE37SM-RS232_03711722_2015_11_18_flag.cnv'
config = dv.ChartConfig(
    title = source,
    x_names = [],
    y_names = ["t090C", 'c0S/m'],
    z_names = [],
    chart_type = "overlay",
    bounds={
        # 'x': { 0: [6700, 6950] },
        # 'y': { 0: [29, 32], 1: [29, 32], 2: [29, 32], 3: [29, 32] }
        },
    plot_loop_edit_flags=True,
    lift_pen_over_bad_data=False
)

data = dv.ChartData(source, config)

line = dv.plot_xy_chart(data, config)
line.show()

# %%
# Example when calling plotting functions directly

from sbs.visualization import data_visualization as dv


source = 'orca-test-data\SBE37SM\SBE37SM-RS232_03711722_2015_11_18\SBE37SM-RS232_03711722_2015_11_18_flag.cnv'
config = dv.ChartConfig(
    title = source,
    x_names = [],
    y_names = ["t090C", 'c0S/m'],
    z_names = [],
    chart_type = "overlay",
    bounds={
        # 'x': { 0: [6700, 6950] },
        # 'y': { 0: [29, 32], 1: [29, 32], 2: [29, 32], 3: [29, 32] }
        },
    plot_loop_edit_flags=True,
    lift_pen_over_bad_data=True
)

data = dv.ChartData(source, config)

line = dv.plot_xy_chart(data, config)
line.show()

# %%
# Example when calling plotting functions directly

from sbs.visualization import data_visualization as dv


source = 'orca-test-data\SBE37SM\SBE37SM-RS232_03711722_2015_11_18\SBE37SM-RS232_03711722_2015_11_18_flag.cnv'
config = dv.ChartConfig(
    title = source,
    x_names = [],
    y_names = ["t090C", 'c0S/m'],
    z_names = [],
    chart_type = "overlay",
    bounds={
        # 'x': { 0: [6700, 6950] },
        # 'y': { 0: [29, 32], 1: [29, 32], 2: [29, 32], 3: [29, 32] }
        },
    plot_loop_edit_flags=False,
    lift_pen_over_bad_data=True
)

data = dv.ChartData(source, config)

line = dv.plot_xy_chart(data, config)
line.show()
